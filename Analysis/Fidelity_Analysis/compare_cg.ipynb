# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['text.latex.preamble']=r"\usepackage{lmodern}"
#Options
params = {'text.usetex' : True,
          'font.size' : 10,
          'font.family' : 'lmodern'
          }
plt.rcParams.update(params) 

import matplotlib.transforms as mtransforms

# %%
overlap_u_28_DT_RK4 = np.load("DT_overlap/overlap_10_28_2000/overlap_u_list.npy")
overlap_v_28_DT_RK4 = np.load("DT_overlap/overlap_10_28_2000/overlap_v_list.npy")
time_28_DT_RK4 = np.load("DT_overlap/overlap_10_28_2000/time_list.npy")

overlap_u_28_DT_RK2 = np.load("DT_overlap/RK2overlap_10_28_2000/overlap_u_list.npy")
overlap_v_28_DT_RK2 = np.load("DT_overlap/RK2overlap_10_28_2000/overlap_v_list.npy")
time_28_DT_RK2 = np.load("DT_overlap/RK2overlap_10_28_2000/time_list.npy")

overlap_u_60_DT_RK4 = np.load("DT_overlap/overlap_10_60_2000/overlap_u_list.npy")
overlap_v_60_DT_RK4 = np.load("DT_overlap/overlap_10_60_2000/overlap_v_list.npy")
time_60_DT_RK4 = np.load("DT_overlap/overlap_10_60_2000/time_list.npy")

overlap_u_60_DT_RK2 = np.load("DT_overlap/RK2overlap_10_60_2000/overlap_u_list.npy")
overlap_v_60_DT_RK2 = np.load("DT_overlap/RK2overlap_10_60_2000/overlap_v_list.npy")
time_60_DT_RK2 = np.load("DT_overlap/RK2overlap_10_60_2000/time_list.npy")

overlap_u_107_DT_RK4 = np.load("DT_overlap/overlap_10_107_2000/overlap_u_list.npy")
overlap_v_107_DT_RK4 = np.load("DT_overlap/overlap_10_107_2000/overlap_v_list.npy")
time_107_DT_RK4 = np.load("DT_overlap/overlap_10_107_2000/time_list.npy")

overlap_u_107_DT_RK2 = np.load("DT_overlap/RK2overlap_10_107_2000/overlap_u_list.npy")
overlap_v_107_DT_RK2 = np.load("DT_overlap/RK2overlap_10_107_2000/overlap_v_list.npy")
time_107_DT_RK2 = np.load("DT_overlap/RK2overlap_10_107_2000/time_list.npy")

# %%
overlap_u_16_DJ_RK4 = np.load("DJ_overlap/overlap_10_16_200000.0/overlap_u_list.npy")
overlap_v_16_DJ_RK4 = np.load("DJ_overlap/overlap_10_16_200000.0/overlap_v_list.npy")
time_16_DJ_RK4 = np.load("DJ_overlap/overlap_10_16_200000.0/time_list.npy")

overlap_u_16_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_16_200000.0/overlap_u_list.npy")
overlap_v_16_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_16_200000.0/overlap_v_list.npy")
time_16_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_16_200000.0/time_list.npy")

overlap_u_39_DJ_RK4 = np.load("DJ_overlap/overlap_10_39_200000.0/overlap_u_list.npy")
overlap_v_39_DJ_RK4 = np.load("DJ_overlap/overlap_10_39_200000.0/overlap_v_list.npy")
time_39_DJ_RK4 = np.load("DJ_overlap/overlap_10_39_200000.0/time_list.npy")

overlap_u_39_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_39_200000.0/overlap_u_list.npy")
overlap_v_39_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_39_200000.0/overlap_v_list.npy")
time_39_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_39_200000.0/time_list.npy")

overlap_u_112_DJ_RK4 = np.load("DJ_overlap/overlap_10_112_200000.0/overlap_u_list.npy")
overlap_v_112_DJ_RK4 = np.load("DJ_overlap/overlap_10_112_200000.0/overlap_v_list.npy")
time_112_DJ_RK4 = np.load("DJ_overlap/overlap_10_112_200000.0/time_list.npy")

overlap_u_112_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_112_200000.0/overlap_u_list.npy")
overlap_v_112_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_112_200000.0/overlap_v_list.npy")
time_112_DJ_RK2 = np.load("DJ_overlap/RK2overlap_10_112_200000.0/time_list.npy")

# %%
plt.plot(time_28_DT_RK2, overlap_u_28_DT_RK2, label="RK2 - u - 28", ls='dashed')
plt.plot(time_28_DT_RK2, overlap_v_28_DT_RK2, label="RK2 - v - 28", ls='dashed')
plt.plot(time_28_DT_RK4, overlap_u_28_DT_RK4, label="RK4 - u - 28")
plt.plot(time_28_DT_RK4, overlap_v_28_DT_RK4, label="RK4 - v - 28")
plt.legend()

# %%
plt.plot(time_60_DT_RK2, overlap_u_60_DT_RK2, label="RK2 - u - 60", ls='dashed')
plt.plot(time_60_DT_RK2, overlap_v_60_DT_RK2, label="RK2 - v - 60", ls='dashed')
plt.plot(time_60_DT_RK4, overlap_u_60_DT_RK4, label="RK4 - u - 60")
plt.plot(time_60_DT_RK4, overlap_v_60_DT_RK4, label="RK4 - v - 60")
plt.legend()

# %%
plt.plot(time_107_DT_RK2, overlap_u_107_DT_RK2, label="RK2 - u - 107", ls='dashed')
plt.plot(time_107_DT_RK2, overlap_v_107_DT_RK2, label="RK2 - v - 107", ls='dashed')
plt.plot(time_107_DT_RK4, overlap_u_107_DT_RK4, label="RK4 - u - 107")
plt.plot(time_107_DT_RK4, overlap_v_107_DT_RK4, label="RK4 - v - 107")
plt.legend()

# %%
plt.plot(time_16_DJ_RK2, overlap_u_16_DJ_RK2, label="RK2 - u - 16", ls='dashed')
plt.plot(time_16_DJ_RK2, overlap_v_16_DJ_RK2, label="RK2 - v - 16", ls='dashed')
plt.plot(time_16_DJ_RK4, overlap_u_16_DJ_RK4, label="RK4 - u - 16")
plt.plot(time_16_DJ_RK4, overlap_v_16_DJ_RK4, label="RK4 - v - 16")
plt.legend()

# %%
plt.plot(time_39_DJ_RK2, overlap_u_39_DJ_RK2, label="RK2 - u - 39", ls='dashed')
plt.plot(time_39_DJ_RK2, overlap_v_39_DJ_RK2, label="RK2 - v - 39", ls='dashed')
plt.plot(time_39_DJ_RK4, overlap_u_39_DJ_RK4, label="RK4 - u - 39")
plt.plot(time_39_DJ_RK4, overlap_v_39_DJ_RK4, label="RK4 - v - 39")
plt.legend()

# %%
plt.plot(time_112_DJ_RK2, overlap_u_112_DJ_RK2, label="RK2 - u - 112", ls='dashed')
plt.plot(time_112_DJ_RK2, overlap_v_112_DJ_RK2, label="RK2 - v - 112", ls='dashed')
plt.plot(time_112_DJ_RK4, overlap_u_112_DJ_RK4, label="RK4 - u - 112")
plt.plot(time_112_DJ_RK4, overlap_v_112_DJ_RK4, label="RK4 - v - 112")
plt.legend()

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True, sharey=True, gridspec_kw={'hspace': 0.3, 'wspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_16_DJ_RK4, overlap_u_16_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 0].plot(time_39_DJ_RK4, overlap_u_39_DJ_RK4**2, label=r"$\epsilon=0.01$")
ax[0, 0].plot(time_112_DJ_RK4, overlap_u_112_DJ_RK4**2, label=r"$\epsilon=0.001$")
ax[0, 0].set_ylabel(r"Fidelity")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 2])
ax[0, 0].set_xticks([0, 1, 2])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 1.05])
ax[0, 0].set_yticks([0, 0.5, 1])
ax[0, 0].set_yticks([0.25, 0.75], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_16_DJ_RK4, overlap_v_16_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 1].plot(time_39_DJ_RK4, overlap_v_39_DJ_RK4**2, label=r"$\epsilon=0.01$")
ax[0, 1].plot(time_112_DJ_RK4, overlap_v_112_DJ_RK2**2, label=r"$\epsilon=0.001$")
# ax[0, 1].set_ylabel(r"$F_2$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(0.05, 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 1.05])
ax[0, 1].set_yticks([0, 0.5, 1])
ax[0, 1].set_yticks([0.25, 0.75], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_28_DT_RK4, overlap_u_28_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 0].plot(time_60_DT_RK4, overlap_u_60_DT_RK4**2, label=r"$\epsilon=0.01$")
ax[1, 0].plot(time_107_DT_RK4, overlap_u_107_DT_RK4**2, label=r"$\epsilon=0.005$")
ax[1, 0].set_ylabel(r"Fidelity")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 1.05])
ax[1, 0].set_yticks([0, 0.5, 1])
ax[1, 0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_28_DT_RK4, overlap_v_28_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 1].plot(time_60_DT_RK4, overlap_v_60_DT_RK4**2, label=r"$\epsilon=0.01$")
ax[1, 1].plot(time_107_DT_RK4, overlap_v_107_DT_RK4**2, label=r"$\epsilon=0.001$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(0.05, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.05])
ax[1, 1].set_yticks([0, 0.5, 1])
ax[1, 1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $u_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $u_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $u_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $u_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.5, -0.03), ncol=2, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"fidelities_examples_low_Re.pdf", bbox_inches="tight")
# Out:
# /var/folders/by/tjkhpdvj401cj92bnwvg228h0000gn/T/ipykernel_15370/2373106354.py:78: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 2, figsize=(3, 1), sharex=True, sharey=True, gridspec_kw={'hspace': 0.3, 'wspace': 0.3})

# BOTTOM LEFT (1, 0)
ax[0].plot(time_28_DT_RK4, overlap_u_28_DT_RK4**2, label=r"$\chi=28$")
ax[0].plot(time_60_DT_RK4, overlap_u_60_DT_RK4**2, label=r"$\chi=60$")
ax[0].plot(time_107_DT_RK4, overlap_u_107_DT_RK4**2, label=r"$\chi=107$")
ax[0].set_ylabel(r"Fidelity")
ax[0].set_xlabel("Time")
ax[0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0].text(-0.15, 0.9, "(c)", transform=ax[0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0].set_xlim([0, 2])
ax[0].set_xticks([0, 1, 2])
ax[0].set_xticks([0.5, 1.5], minor=True)
ax[0].set_ylim([0, 1.05])
ax[0].set_yticks([0, 0.5, 1])
ax[0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1].plot(time_28_DT_RK4, overlap_v_28_DT_RK4**2, label=r"$\chi=28$")
ax[1].plot(time_60_DT_RK4, overlap_v_60_DT_RK4**2, label=r"$\chi=60$")
ax[1].plot(time_107_DT_RK4, overlap_v_107_DT_RK4**2, label=r"$\chi=107$")
ax[1].set_xlabel("Time")
ax[1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1].text(0.1, 0.9, "(d)", transform=ax[1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1].set_xlim([0, 2])
ax[1].set_xticks([0, 1, 2])
ax[1].set_xticks([0.5, 1.5], minor=True)
ax[1].set_ylim([0, 1.05])
ax[1].set_yticks([0, 0.5, 1])
ax[1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
ax[0].set_title(r"DT, $u_1$", fontsize=10)
ax[1].set_title(r"DT, $u_2$", fontsize=10)
fig.legend(*ax[0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.5, -0.03), ncol=3, fancybox=True, handlelength=1, handletextpad=0.5, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"fidelities_examples_low_Re.pdf", bbox_inches="tight")
# Out:
# /var/folders/by/tjkhpdvj401cj92bnwvg228h0000gn/T/ipykernel_15370/1661901770.py:42: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 2, figsize=(3.5, 1.5), sharex=True, sharey=True, gridspec_kw={'hspace': 0.3, 'wspace': 0.3})

# BOTTOM LEFT (1, 0)
ax[0].plot(time_16_DJ_RK4, overlap_u_16_DJ_RK4**2, label=r"$\chi=16$")
ax[0].plot(time_39_DJ_RK4, overlap_u_39_DJ_RK4**2, label=r"$\chi=39$")
ax[0].plot(time_112_DJ_RK4, overlap_u_112_DJ_RK4**2, label=r"$\chi=112$")
ax[0].set_ylabel(r"Fidelity")
ax[0].set_xlabel("Time")
ax[0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0].text(-0.15, 0.9, "(a)", transform=ax[0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0].set_xlim([0, 2])
ax[0].set_xticks([0, 1, 2])
ax[0].set_xticks([0.5, 1.5], minor=True)
ax[0].set_ylim([0, 1.05])
ax[0].set_yticks([0, 0.5, 1])
ax[0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1].plot(time_16_DJ_RK4, overlap_v_16_DJ_RK4**2, label=r"$\chi=28$")
ax[1].plot(time_39_DJ_RK4, overlap_v_39_DJ_RK4**2, label=r"$\chi=60$")
ax[1].plot(time_112_DJ_RK4, overlap_v_112_DJ_RK2**2, label=r"$\chi=107$")
ax[1].set_xlabel("Time")
ax[1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1].text(0.05, 0.9, "(b)", transform=ax[1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1].set_xlim([0, 2])
ax[1].set_xticks([0, 1, 2])
ax[1].set_xticks([0.5, 1.5], minor=True)
ax[1].set_ylim([0, 1.05])
ax[1].set_yticks([0, 0.5, 1])
ax[1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
fig.legend(*ax[0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3, fancybox=True, handlelength=1, handletextpad=0.5, columnspacing=0.8)
fig.tight_layout()
ax[0].set_title(r"DJ, $u_1$", fontsize=10)
ax[1].set_title(r"DJ, $u_2$", fontsize=10)

plt.savefig(f"fidelities_examples_low_Re.pdf", bbox_inches="tight")
# Out:
# /var/folders/by/tjkhpdvj401cj92bnwvg228h0000gn/T/ipykernel_15370/1421774679.py:40: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# # Re = 1e7

# %%
overlap_u_17_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_17_10000000.0/overlap_u_list.npy")
overlap_v_17_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_17_10000000.0/overlap_v_list.npy")
time_17_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_17_10000000.0/time_list.npy")

overlap_u_72_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_72_10000000.0/overlap_u_list.npy")
overlap_v_72_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_72_10000000.0/overlap_v_list.npy")
time_72_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_72_10000000.0/time_list.npy")

overlap_u_94_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_94_10000000.0/overlap_u_list.npy")
overlap_v_94_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_94_10000000.0/overlap_v_list.npy")
time_94_DJ_RK4 = np.load("DJ_overlap_1e7/overlap_11_94_10000000.0/time_list.npy")

overlap_u_20_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_20_10000000.0/overlap_u_list.npy")
overlap_v_20_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_20_10000000.0/overlap_v_list.npy")
time_20_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_20_10000000.0/time_list.npy")

overlap_u_137_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_137_10000000.0/overlap_u_list.npy")
overlap_v_137_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_137_10000000.0/overlap_v_list.npy")
time_137_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_137_10000000.0/time_list.npy")

overlap_u_190_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_190_10000000.0/overlap_u_list.npy")
overlap_v_190_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_190_10000000.0/overlap_v_list.npy")
time_190_DT_RK4 = np.load("DT_overlap_1e7/overlap_11_190_10000000.0/time_list.npy")

# %%
plt.plot(time_17_DJ_RK4, overlap_u_17_DJ_RK4, label="RK4 - u - 17")
plt.plot(time_72_DJ_RK4, overlap_u_72_DJ_RK4, label="RK4 - u - 72")
plt.plot(time_94_DJ_RK4, overlap_u_94_DJ_RK4, label="RK4 - u - 94")
plt.legend()
plt.ylim([0,1])
plt.show()

plt.plot(time_17_DJ_RK4, overlap_v_17_DJ_RK4, label="RK4 - v - 17")
plt.plot(time_72_DJ_RK4, overlap_v_72_DJ_RK4, label="RK4 - v - 72")
plt.plot(time_94_DJ_RK4, overlap_v_94_DJ_RK4, label="RK4 - v - 94")
plt.legend()
plt.ylim([0,1])
plt.show()

# %%
plt.plot(time_20_DT_RK4, overlap_u_20_DT_RK4, label="RK4 - u - 20")
plt.plot(time_137_DT_RK4, overlap_u_137_DT_RK4, label="RK4 - u - 137")
plt.plot(time_190_DT_RK4, overlap_u_190_DT_RK4, label="RK4 - u - 190")
plt.legend()
plt.ylim([0,1])
plt.show()

plt.plot(time_20_DT_RK4, overlap_v_20_DT_RK4, label="RK4 - v - 20")
plt.plot(time_137_DT_RK4, overlap_v_137_DT_RK4, label="RK4 - v - 137")
plt.plot(time_190_DT_RK4, overlap_v_190_DT_RK4, label="RK4 - v - 190")
plt.legend()
plt.ylim([0,1])
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True)#,  gridspec_kw={'wspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_17_DJ_RK4, overlap_u_17_DJ_RK4, label=r"$\epsilon=0.1$")
ax[0, 0].plot(time_72_DJ_RK4, overlap_u_72_DJ_RK4, label=r"$\epsilon=0.01$")
ax[0, 0].plot(time_94_DJ_RK4, overlap_u_94_DJ_RK4, label=r"$\epsilon=0.005$")
ax[0, 0].set_ylabel(r"$\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle$")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 2])
ax[0, 0].set_xticks([0, 1, 2])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 1.05])
ax[0, 0].set_yticks([0, 0.5, 1])
ax[0, 0].set_yticks([0.25, 0.75], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_17_DJ_RK4, overlap_v_17_DJ_RK4, label=r"$\epsilon=0.1$")
ax[0, 1].plot(time_72_DJ_RK4, overlap_v_72_DJ_RK4, label=r"$\epsilon=0.01$")
ax[0, 1].plot(time_94_DJ_RK4, overlap_v_94_DJ_RK4, label=r"$\epsilon=0.005$")
ax[0, 1].set_ylabel(r"$\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(-0.15, 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 1.05])
ax[0, 1].set_yticks([0, 0.5, 1])
ax[0, 1].set_yticks([0.25, 0.75], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_20_DT_RK4, overlap_u_20_DT_RK4, label=r"$\epsilon=0.1$")
ax[1, 0].plot(time_137_DT_RK4, overlap_u_137_DT_RK4, label=r"$\epsilon=0.01$")
ax[1, 0].plot(time_190_DT_RK4, overlap_u_190_DT_RK4, label=r"$\epsilon=0.005$")
ax[1, 0].set_ylabel(r"$\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle$")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 1.05])
ax[1, 0].set_yticks([0, 0.5, 1])
ax[1, 0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_20_DT_RK4, overlap_v_20_DT_RK4, label=r"$\epsilon=0.1$")
ax[1, 1].plot(time_137_DT_RK4, overlap_v_137_DT_RK4, label=r"$\epsilon=0.01$")
ax[1, 1].plot(time_190_DT_RK4, overlap_v_190_DT_RK4, label=r"$\epsilon=0.001$")
ax[1, 1].set_ylabel(r"$\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(-0.15, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.05])
ax[1, 1].set_yticks([0, 0.5, 1])
ax[1, 1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $x_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $x_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $x_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $x_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.555, 0.05), ncol=9, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"overlap_examples.pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True)#,  gridspec_kw={'wspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_17_DJ_RK4, overlap_u_17_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 0].plot(time_72_DJ_RK4, overlap_u_72_DJ_RK4**2, label=r"$\epsilon=0.01$")
ax[0, 0].plot(time_94_DJ_RK4, overlap_u_94_DJ_RK4**2, label=r"$\epsilon=0.005$")
ax[0, 0].set_ylabel(r"$|\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle|^2$")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 2])
ax[0, 0].set_xticks([0, 1, 2])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 1.05])
ax[0, 0].set_yticks([0, 0.5, 1])
ax[0, 0].set_yticks([0.25, 0.75], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_17_DJ_RK4, overlap_v_17_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 1].plot(time_72_DJ_RK4, overlap_v_72_DJ_RK4**2, label=r"$\epsilon=0.01$")
ax[0, 1].plot(time_94_DJ_RK4, overlap_v_94_DJ_RK4**2, label=r"$\epsilon=0.005$")
ax[0, 1].set_ylabel(r"$|\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle|^2$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(-0.15, 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 1.05])
ax[0, 1].set_yticks([0, 0.5, 1])
ax[0, 1].set_yticks([0.25, 0.75], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_20_DT_RK4, overlap_u_20_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 0].plot(time_137_DT_RK4, overlap_u_137_DT_RK4**2, label=r"$\epsilon=0.01$")
ax[1, 0].plot(time_190_DT_RK4, overlap_u_190_DT_RK4**2, label=r"$\epsilon=0.005$")
ax[1, 0].set_ylabel(r"$|\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle|^2$")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 1.05])
ax[1, 0].set_yticks([0, 0.5, 1])
ax[1, 0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_20_DT_RK4, overlap_v_20_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 1].plot(time_137_DT_RK4, overlap_v_137_DT_RK4**2, label=r"$\epsilon=0.01$")
ax[1, 1].plot(time_190_DT_RK4, overlap_v_190_DT_RK4**2, label=r"$\epsilon=0.001$")
ax[1, 1].set_ylabel(r"$|\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle|^2$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(-0.15, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.05])
ax[1, 1].set_yticks([0, 0.5, 1])
ax[1, 1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $x_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $x_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $x_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $x_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.555, 0.05), ncol=9, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"fidelities_examples.pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True)#,  gridspec_kw={'wspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_17_DJ_RK4, overlap_u_17_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 0].plot(time_72_DJ_RK4, overlap_u_72_DJ_RK4**2, label=r"$\epsilon=0.01$")
# ax[0, 0].plot(time_94_DJ_RK4, overlap_u_94_DJ_RK4**2, label=r"$\epsilon=0.005$")
ax[0, 0].set_ylabel(r"$|\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle|^2$")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 2])
ax[0, 0].set_xticks([0, 1, 2])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 1.05])
ax[0, 0].set_yticks([0, 0.5, 1])
ax[0, 0].set_yticks([0.25, 0.75], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_17_DJ_RK4, overlap_v_17_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 1].plot(time_72_DJ_RK4, overlap_v_72_DJ_RK4**2, label=r"$\epsilon=0.01$")
# ax[0, 1].plot(time_94_DJ_RK4, overlap_v_94_DJ_RK4**2, label=r"$\epsilon=0.005$")
ax[0, 1].set_ylabel(r"$|\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle|^2$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(-0.15, 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 1.05])
ax[0, 1].set_yticks([0, 0.5, 1])
ax[0, 1].set_yticks([0.25, 0.75], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_20_DT_RK4, overlap_u_20_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 0].plot(time_137_DT_RK4, overlap_u_137_DT_RK4**2, label=r"$\epsilon=0.01$")
# ax[1, 0].plot(time_190_DT_RK4, overlap_u_190_DT_RK4**2, label=r"$\epsilon=0.005$")
ax[1, 0].set_ylabel(r"$|\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle|^2$")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 1.05])
ax[1, 0].set_yticks([0, 0.5, 1])
ax[1, 0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_20_DT_RK4, overlap_v_20_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 1].plot(time_137_DT_RK4, overlap_v_137_DT_RK4**2, label=r"$\epsilon=0.01$")
# ax[1, 1].plot(time_190_DT_RK4, overlap_v_190_DT_RK4**2, label=r"$\epsilon=0.001$")
ax[1, 1].set_ylabel(r"$|\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle|^2$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(-0.15, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.05])
ax[1, 1].set_yticks([0, 0.5, 1])
ax[1, 1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $x_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $x_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $x_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $x_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.555, 0.05), ncol=2, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"fidelities_examples.pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True, sharey=True, gridspec_kw={'hspace': 0.3, 'wspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_17_DJ_RK4, overlap_u_17_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 0].plot(time_72_DJ_RK4, overlap_u_72_DJ_RK4**2, label=r"$\epsilon=0.01$")
# ax[0, 0].plot(time_94_DJ_RK4, overlap_u_94_DJ_RK4**2, label=r"$\epsilon=0.005$")
ax[0, 0].set_ylabel(r"Fidelity")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 2])
ax[0, 0].set_xticks([0, 1, 2])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 1.05])
ax[0, 0].set_yticks([0, 0.5, 1])
ax[0, 0].set_yticks([0.25, 0.75], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_17_DJ_RK4, overlap_v_17_DJ_RK4**2, label=r"$\epsilon=0.1$")
ax[0, 1].plot(time_72_DJ_RK4, overlap_v_72_DJ_RK4**2, label=r"$\epsilon=0.01$")
# ax[0, 1].plot(time_94_DJ_RK4, overlap_v_94_DJ_RK4**2, label=r"$\epsilon=0.005$")
# ax[0, 1].set_ylabel(r"$F_2$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(0.05, 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 1.05])
ax[0, 1].set_yticks([0, 0.5, 1])
ax[0, 1].set_yticks([0.25, 0.75], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_20_DT_RK4, overlap_u_20_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 0].plot(time_137_DT_RK4, overlap_u_137_DT_RK4**2, label=r"$\epsilon=0.01$")
# ax[1, 0].plot(time_190_DT_RK4, overlap_u_190_DT_RK4**2, label=r"$\epsilon=0.005$")
ax[1, 0].set_ylabel(r"Fidelity")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 1.05])
ax[1, 0].set_yticks([0, 0.5, 1])
ax[1, 0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_20_DT_RK4, overlap_v_20_DT_RK4**2, label=r"$\epsilon=0.1$")
ax[1, 1].plot(time_137_DT_RK4, overlap_v_137_DT_RK4**2, label=r"$\epsilon=0.01$")
# ax[1, 1].plot(time_190_DT_RK4, overlap_v_190_DT_RK4**2, label=r"$\epsilon=0.001$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(0.05, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.05])
ax[1, 1].set_yticks([0, 0.5, 1])
ax[1, 1].set_yticks([0.25, 0.75], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $u_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $u_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $u_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $u_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.5, -0.03), ncol=2, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"fidelities_examples.pdf", bbox_inches="tight")
# Out:
# /var/folders/by/tjkhpdvj401cj92bnwvg228h0000gn/T/ipykernel_15370/3832147291.py:78: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True, sharey=True,  gridspec_kw={'hspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_17_DJ_RK4, np.sqrt(2-2*overlap_u_17_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[0, 0].plot(time_72_DJ_RK4, np.sqrt(2-2*overlap_u_72_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
ax[0, 0].plot(time_94_DJ_RK4, np.sqrt(2-2*overlap_u_94_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.005$")
ax[0, 0].set_ylabel(r"$\epsilon$")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 1.5])
ax[0, 0].set_xticks([0, 1])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 2])
ax[0, 0].set_yticks([0, 1, 2.0])
ax[0, 0].set_yticks([0.5, 1.5], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_17_DJ_RK4, np.sqrt(2-2*overlap_v_17_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[0, 1].plot(time_72_DJ_RK4, np.sqrt(2-2*overlap_v_72_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
ax[0, 1].plot(time_94_DJ_RK4, np.sqrt(2-2*overlap_v_94_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.005$")
# ax[0, 1].set_ylabel(r"$\epsilon$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(-0.15, 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 2])
ax[0, 1].set_yticks([0, 1, 2.0])
ax[0, 1].set_yticks([0.5, 1.5], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_20_DT_RK4, np.sqrt(2-2*overlap_u_20_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[1, 0].plot(time_137_DT_RK4, np.sqrt(2-2*overlap_u_137_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
ax[1, 0].plot(time_190_DT_RK4, np.sqrt(2-2*overlap_u_190_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.005$")
ax[1, 0].set_ylabel(r"$\epsilon$")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 2])
ax[1, 0].set_yticks([0, 1, 2.0])
ax[1, 0].set_yticks([0.5, 1.5], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_20_DT_RK4, np.sqrt(2-2*overlap_v_20_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[1, 1].plot(time_137_DT_RK4, np.sqrt(2-2*overlap_v_137_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
ax[1, 1].plot(time_190_DT_RK4, np.sqrt(2-2*overlap_v_190_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.001$")
# ax[1, 1].set_ylabel(r"$\epsilon$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(-0.15, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.5])
ax[1, 1].set_yticks([0, 0.5, 1, 1.5])
ax[1, 1].set_yticks([0.5, 1.5], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $x_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $x_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $x_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $x_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.555, 0.05), ncol=9, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"overlap_examples.pdf", bbox_inches="tight")
# Out:
# /var/folders/by/tjkhpdvj401cj92bnwvg228h0000gn/T/ipykernel_15370/3214958442.py:79: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True, sharey=True,  gridspec_kw={'hspace': 0.3, 'wspace': 0.3})

# TOP LEFT (0, 0)
ax[0, 0].plot(time_17_DJ_RK4, np.sqrt(2-2*overlap_u_17_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[0, 0].plot(time_72_DJ_RK4, np.sqrt(2-2*overlap_u_72_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
# ax[0, 0].plot(time_94_DJ_RK4, np.sqrt(2-2*overlap_u_94_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.005$")
ax[0, 0].set_ylabel(r"$\epsilon$")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.1, 0.9, "(a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 1.5])
ax[0, 0].set_xticks([0, 1])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 2])
ax[0, 0].set_yticks([0, 1, 2.0])
ax[0, 0].set_yticks([0.5, 1.5], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_17_DJ_RK4, np.sqrt(2-2*overlap_v_17_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[0, 1].plot(time_72_DJ_RK4, np.sqrt(2-2*overlap_v_72_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
# ax[0, 1].plot(time_94_DJ_RK4, np.sqrt(2-2*overlap_v_94_DJ_RK4), label=r"$\epsilon_\mathrm{max}=0.005$")
# ax[0, 1].set_ylabel(r"$\epsilon$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(0., 0.9, "(b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 2])
ax[0, 1].set_yticks([0, 1, 2.0])
ax[0, 1].set_yticks([0.5, 1.5], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_20_DT_RK4, np.sqrt(2-2*overlap_u_20_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[1, 0].plot(time_137_DT_RK4, np.sqrt(2-2*overlap_u_137_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
# ax[1, 0].plot(time_190_DT_RK4, np.sqrt(2-2*overlap_u_190_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.005$")
ax[1, 0].set_ylabel(r"$\epsilon$")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.1, 0.9, "(c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 2])
ax[1, 0].set_yticks([0, 1, 2.0])
ax[1, 0].set_yticks([0.5, 1.5], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_20_DT_RK4, np.sqrt(2-2*overlap_v_20_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.1$")
ax[1, 1].plot(time_137_DT_RK4, np.sqrt(2-2*overlap_v_137_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.01$")
# ax[1, 1].plot(time_190_DT_RK4, np.sqrt(2-2*overlap_v_190_DT_RK4), label=r"$\epsilon_\mathrm{max}=0.001$")
# ax[1, 1].set_ylabel(r"$\epsilon$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(0.05, 0.9, "(d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.5])
ax[1, 1].set_yticks([0, 0.5, 1, 1.5])
ax[1, 1].set_yticks([0.5, 1.5], minor=True)

# GENERAL SETTINGS
ax[0, 0].set_title(r"DJ, $x_1$", fontsize=10)
ax[0, 1].set_title(r"DJ, $x_2$", fontsize=10)
ax[1, 0].set_title(r"DT, $x_1$", fontsize=10)
ax[1, 1].set_title(r"DT, $x_2$", fontsize=10)
fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.5, 0.0), ncol=9, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"error_qis_dns.pdf", bbox_inches="tight")
# Out:
# /var/folders/by/tjkhpdvj401cj92bnwvg228h0000gn/T/ipykernel_15370/3572387100.py:79: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
