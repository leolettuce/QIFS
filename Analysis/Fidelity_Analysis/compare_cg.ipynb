# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['text.latex.preamble']=r"\usepackage{lmodern}"
#Options
params = {'text.usetex' : True,
          'font.size' : 10,
          'font.family' : 'lmodern'
          }
plt.rcParams.update(params) 

import matplotlib.transforms as mtransforms

# %% [markdown]
# # Decaying Jet (DJ) Scenario

# %% [markdown]
# # $\chi=16$

# %%
overlap_u_16_100 = np.load("DJ/overlap_10_16_200000/overlap_u_list.npy")
overlap_v_16_100 = np.load("DJ/overlap_10_16_200000/overlap_v_list.npy")
time_list_16_100 = np.load("DJ/overlap_10_16_200000/time_list.npy")

# %%
plt.plot(time_list_16_100, overlap_u_16_100)

# %%
plt.plot(time_list_16_100, overlap_v_16_100)

# %% [markdown]
# # $\chi=39$

# %%
overlap_u_39_100 = np.load("DJ/overlap_10_39_200000/overlap_u_list.npy")
overlap_v_39_100 = np.load("DJ/overlap_10_39_200000/overlap_v_list.npy")
time_list_39_100 = np.load("DJ/overlap_10_39_200000/time_list.npy")

# %%
plt.plot(time_list_39_100, overlap_u_39_100)

# %%
plt.plot(time_list_39_100, overlap_v_39_100)

# %% [markdown]
# # $\chi=112$

# %%
overlap_u_112_100 = np.load("DJ/overlap_10_112_200000/overlap_u_list.npy")
overlap_v_112_100 = np.load("DJ/overlap_10_112_200000/overlap_v_list.npy")
time_list_112_100 = np.load("DJ/overlap_10_112_200000/time_list.npy")

# %%
plt.plot(time_list_112_100, overlap_u_112_100)

# %%
plt.plot(time_list_112_100, overlap_v_112_100)

# %% [markdown]
# # Compare all

# %%
plt.plot(time_list_16_100, overlap_u_16_100)
plt.plot(time_list_39_100, overlap_u_39_100)
plt.plot(time_list_112_100, overlap_u_112_100)

# %%
plt.plot(time_list_16_100, overlap_v_16_100)
plt.plot(time_list_39_100, overlap_v_39_100)
plt.plot(time_list_112_100, overlap_v_112_100)
# plt.yscale('log')

# %% [markdown]
# # Decaying Turbulence (DT) Scenario

# %%
overlap_u_28 = np.load("DT/overlap_10_28_2000/overlap_u_list.npy")
overlap_v_28 = np.load("DT/overlap_10_28_2000/overlap_u_list.npy")
time_list_28 = np.load("DT/overlap_10_28_2000/time_list.npy")

overlap_u_60 = np.load("DT/overlap_10_60_2000/overlap_u_list.npy")
overlap_v_60 = np.load("DT/overlap_10_60_2000/overlap_u_list.npy")
time_list_60 = np.load("DT/overlap_10_60_2000/time_list.npy")

overlap_u_107 = np.load("DT/overlap_10_107_2000/overlap_u_list.npy")
overlap_v_107 = np.load("DT/overlap_10_107_2000/overlap_u_list.npy")
time_list_107 = np.load("DT/overlap_10_107_2000/time_list.npy")

# %%
plt.plot(time_list_28, overlap_u_28)
plt.plot(time_list_60, overlap_u_60)
plt.plot(time_list_107, overlap_u_107)

# %%
plt.plot(time_list_28, overlap_v_28)
plt.plot(time_list_60, overlap_v_60)
plt.plot(time_list_107, overlap_v_107)

# %%
fig, ax = plt.subplots(2, 2, figsize=(3.5, 3), sharex=True)

# TOP LEFT (0, 0)
ax[0, 0].plot(time_list_16_100, overlap_u_16_100**2, label=r"$\epsilon=0.1$")
ax[0, 0].plot(time_list_39_100, overlap_u_39_100**2, label=r"$\epsilon=0.01$")
ax[0, 0].plot(time_list_112_100, overlap_u_112_100**2, label=r"$\epsilon=0.001$")
# ax[0, 0].plot(t_list, approx_list_09, c="tab:blue", ls="dotted")
# ax[0, 0].plot(t_list, approx_list_099, c="tab:orange", ls="dotted")
# ax[0, 0].plot(t_list, approx_list_0999, c="tab:green", ls="dotted")
ax[0, 0].set_ylabel(r"$|\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle|^2$")
ax[0, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 0].text(-0.15, 0.9, "a)", transform=ax[0, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 0].set_xlim([0, 2])
ax[0, 0].set_xticks([0, 1, 2])
ax[0, 0].set_xticks([0.5, 1.5], minor=True)
ax[0, 0].set_ylim([0, 1.05])
ax[0, 0].set_yticks([0, 0.5, 1])
ax[0, 0].set_yticks([0.25, 0.75], minor=True)

# TOP RIGHT (0, 1)
ax[0, 1].plot(time_list_16_100, overlap_v_16_100**2, label=r"$\epsilon=0.1$")
ax[0, 1].plot(time_list_39_100, overlap_v_39_100**2, label=r"$\epsilon=0.01$")
ax[0, 1].plot(time_list_112_100, overlap_v_112_100**2, label=r"$\epsilon=0.001$")
# ax[0, 1].plot(t_list, approx_list_09, c="tab:blue", ls="dotted")
# ax[0, 1].plot(t_list, approx_list_099, c="tab:orange", ls="dotted")
# ax[0, 1].plot(t_list, approx_list_0999, c="tab:green", ls="dotted")
ax[0, 1].set_ylabel(r"$|\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle|^2$")
ax[0, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[0, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[0, 1].text(-0.15, 0.9, "b)", transform=ax[0, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[0, 1].set_xlim([0, 2])
ax[0, 1].set_xticks([0, 1, 2])
ax[0, 1].set_xticks([0.5, 1.5], minor=True)
ax[0, 1].set_ylim([0, 1.05])
ax[0, 1].set_yticks([0, 0.5, 1])
ax[0, 1].set_yticks([0.25, 0.75], minor=True)

# BOTTOM LEFT (1, 0)
ax[1, 0].plot(time_list_28, overlap_u_28**2, label=r"$\epsilon=0.1$")
ax[1, 0].plot(time_list_60, overlap_u_60**2, label=r"$\epsilon=0.01$")
ax[1, 0].plot(time_list_107, overlap_u_107**2, label=r"$\epsilon=0.001$")
# ax[1, 0].plot(t_list, approx_list_09, c="tab:blue", ls="dotted")
# ax[1, 0].plot(t_list, approx_list_099, c="tab:orange", ls="dotted")
# ax[1, 0].plot(t_list, approx_list_0999, c="tab:green", ls="dotted")
ax[1, 0].set_ylabel(r"$|\langle u_1^\mathrm{DNS} | u_1^\mathrm{QIS} \rangle|^2$")
ax[1, 0].set_xlabel("Time")
ax[1, 0].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 0].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 0].text(-0.15, 0.9, "c)", transform=ax[1, 0].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 0].set_xlim([0, 2])
ax[1, 0].set_xticks([0, 1, 2])
ax[1, 0].set_xticks([0.5, 1.5], minor=True)
ax[1, 0].set_ylim([0, 1.05])
ax[1, 0].set_yticks([0, 0.5, 1])
ax[1, 0].set_yticks([0.25, 0.75], minor=True)

# BOTTOM RIGHT (1, 1)
ax[1, 1].plot(time_list_28, overlap_v_28**2, label=r"$\epsilon=0.1$")
ax[1, 1].plot(time_list_60, overlap_v_60**2, label=r"$\epsilon=0.01$")
ax[1, 1].plot(time_list_107, overlap_v_107**2, label=r"$\epsilon=0.001$")
# ax[1, 1].plot(t_list, approx_list_09, c="tab:blue", ls="dotted")
# ax[1, 1].plot(t_list, approx_list_099, c="tab:orange", ls="dotted")
# ax[1, 1].plot(t_list, approx_list_0999, c="tab:green", ls="dotted")
ax[1, 1].set_ylabel(r"$|\langle u_2^\mathrm{DNS} | u_2^\mathrm{QIS} \rangle|^2$")
ax[1, 1].set_xlabel("Time")
ax[1, 1].xaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].yaxis.grid(True, which="both", ls="--", c='0.7')
ax[1, 1].tick_params(which='both', direction="in")
trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
ax[1, 1].text(-0.15, 0.9, "d)", transform=ax[1, 1].transAxes + trans, fontsize='medium', va='bottom', fontfamily='serif')
ax[1, 1].set_xlim([0, 2])
ax[1, 1].set_xticks([0, 1, 2])
ax[1, 1].set_xticks([0.5, 1.5], minor=True)
ax[1, 1].set_ylim([0, 1.05])
ax[1, 1].set_yticks([0, 0.5, 1])
ax[1, 1].set_yticks([0.25, 0.75], minor=True)

ax[0, 0].set_title(r"DJ $(x)$", fontsize=10)
ax[0, 1].set_title(r"DJ $(y)$", fontsize=10)
ax[1, 0].set_title(r"DT $(x)$", fontsize=10)
ax[1, 1].set_title(r"DT $(y)$", fontsize=10)

# GENERAL SETTINGS

fig.legend(*ax[0, 0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.555, 0.05), ncol=9, fancybox=True, handlelength=1) #, handletextpad=0.2, columnspacing=0.8)
fig.tight_layout()

plt.savefig(f"fidelity_QIS.pdf", bbox_inches="tight")
