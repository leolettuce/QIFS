# %%
from CFD_2D_TDJ import *

# %%
# Create field
n_bits = 4
N = 2**n_bits
L = 1
chi = 16
chi_mpo = chi

# Set timesteps
dt = 0.1*2**-(n_bits-1)
T = 2

# Set penalty factor for breach of incompressibility condition
dx = 1 / (2**n_bits - 1)
mu = 2.5 * 10**5
Re = 0.001*200*1e3
# Re = 200*1e3

# %%
U_MPS, V_MPS, U_arrays, V_arrays = build_initial_fields(n_bits, L, chi)

# %%
time_evolution(U_MPS, V_MPS, chi, chi_mpo, dt, T, Re, mu, '/home/q541472/dev/cuTensorNet/data')
# Out:
# Step = 0 - Time = 0
#
# Run: 34, Diff: -0.00024092329939867643, E_0: 63.09563369221684, E_1: 63.0804324839700645

# %%
n = 1
contract('apb, apb->', U_MPS[n], U_MPS[n]) + contract('apb, apb->', V_MPS[n], V_MPS[n])
# Out:
# array(63.99576937)

# %%
U_MPS = shift_canonical_center(U_MPS, 0)
V_MPS = shift_canonical_center(V_MPS, 0)

# %%
U_MPS = shift_canonical_center(U_MPS, 1, 0)
V_MPS = shift_canonical_center(V_MPS, 1, 0)

# %%
plot(U_MPS, V_MPS, show=True)
